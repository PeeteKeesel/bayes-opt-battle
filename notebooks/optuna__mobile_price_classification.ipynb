# %%
import pprint
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import optuna

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Comparison of Bayesian Optimization Frameworks
#
# In this notebook we are going to compare different bayesian optimization libraries against each other. To compare our results we will use [Kaggle's Mobile Price Classification](https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification?datasetId=11167&sortBy=voteCount) dataset. We performed a short EDA on this dataset in [notebooks/eda__mobile_price_classification.ipynb](https://github.com/PeeteKeesel/bayes-opt-battle/blob/main/notebooks/eda__mobile_price_classification.ipynb).

# %% [markdown]
# ## Global Settings

# %%
RANDOM_SEED = 42
DATASET_FOLDER = '../datasets/mobile_price_classification'

# %%
train = pd.read_csv(f'{DATASET_FOLDER}/train.csv')
test = pd.read_csv(f'{DATASET_FOLDER}/test.csv')
print(f"""
Shapes
======
    train: {train.shape}
    test : {test.shape}      
""")
train.head(3)
# Out:
# Shapes
# ======
#     train: (2000, 21)
#     test : (1000, 21)
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
#
# [3 rows x 21 columns]

# %%
TARGET = 'price_range'
FEATURES = list(set(train.columns).difference({TARGET}))

# %%
def predict_and_summarize(X_train_scaled,
                          X_test_scaled, 
                          y_train, 
                          y_test,
                          clf,
                          model_type):

    y_pred_train = clf.predict(X_train_scaled)
    train_acc = accuracy_score(y_train, y_pred_train)
    train_prec = precision_score(y_train, y_pred_train, average='macro', zero_division=0)
    train_rec = recall_score(y_train, y_pred_train, average='macro', zero_division=0)
    train_f1 = f1_score(y_train, y_pred_train, average='macro', zero_division=0)

    y_pred = clf.predict(X_test_scaled)
    test_acc = accuracy_score(y_test, y_pred)
    test_prec = precision_score(y_test, y_pred, average='macro', zero_division=0)
    test_rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    test_f1 = f1_score(y_test, y_pred, average='macro', zero_division=0)

    print(f"""
    Performance Results : {model_type} 
    ========================================
                    {'Train':<10}{'Test':<10}
        Accuracy  : {train_acc:<10.4f}{test_acc:<10.4f}
        Precision : {train_prec:<10.4f}{test_prec:<10.4f}
        Recall    : {train_rec:<10.4f}{test_rec:<10.4f}
        F1-Score  : {train_f1:<10.4f}{test_f1:<10.4f}
    """)

    return {'y_pred_train': y_pred_train, 'y_pred_test': y_pred}

# %% [markdown]
# ## Dataset Preparation

# %%
X_train, X_test, y_train, y_test = train_test_split(train[FEATURES],
                                                    train[TARGET], 
                                                    test_size=0.3, 
                                                    random_state=RANDOM_SEED,
                                                    stratify=train[TARGET])

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Baseline Models
#
# Let's train a small baseline model to get a feeling for how much better the bayesian optimizated models will get.

# %% [markdown]
# ### LogisticRegression

# %%
lrc = LogisticRegression()

lrc.fit(X_train_scaled, y_train)

y_preds = predict_and_summarize(X_train_scaled,
                                X_test_scaled, 
                                y_train, 
                                y_test,
                                lrc,
                                'LogisticRegression')
# Out:
#     Performance Results : LogisticRegression
#     ========================================
#                     Train     Test
#         Accuracy  : 0.9764    0.9600
#         Precision : 0.9765    0.9603
#         Recall    : 0.9764    0.9600
#         F1-Score  : 0.9764    0.9600

# %%
cm = confusion_matrix(y_test, y_preds.get('y_pred_test'))
class_labels = np.unique(y_test)

plt.figure(figsize=(3, 2))
sns.heatmap(cm, 
            annot=True, 
            cmap='coolwarm', 
            fmt='d', 
            xticklabels=class_labels, 
            yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('LogisticRegression')
plt.show()

# %% [markdown]
# The model is already strongly predictive. However, let's see if we can improve performance by tuning hyperparameters of a model.

# %% [markdown]
# ### RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=RANDOM_SEED)

rfc.fit(X_train_scaled, y_train)

y_preds = predict_and_summarize(X_train_scaled,
                                X_test_scaled, 
                                y_train, 
                                y_test,
                                rfc,
                                'RandomForestClassifier')
# Out:
#     Performance Results : RandomForestClassifier
#     ========================================
#                     Train     Test
#         Accuracy  : 1.0000    0.8633
#         Precision : 1.0000    0.8623
#         Recall    : 1.0000    0.8633
#         F1-Score  : 1.0000    0.8627

# %%
cm = confusion_matrix(y_test, y_preds.get('y_pred_test'))
class_labels = np.unique(y_test)

plt.figure(figsize=(3, 2))
sns.heatmap(cm, 
            annot=True, 
            cmap='coolwarm', 
            fmt='d', 
            xticklabels=class_labels, 
            yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('RandomForestClassifier')
plt.show()

# %% [markdown]
# The un-tuned random forest classifier is highly overfit and the test performance is lower then the one from the logistic regression.

# %% [markdown]
# ## Bayesian Hyperparameter Optimization
#
# Now we will tune the models hyperparameters using different libraries provided by Python.
#
# We will use `Precision` as our optimization metric.

# %%
X_tra, X_val, y_tra, y_val = train_test_split(X_train,
                                              y_train, 
                                              test_size=0.2, 
                                              random_state=RANDOM_SEED,
                                              stratify=y_train)
print(f"""
Shapes
======
    train : {X_tra.shape}
    val   : {X_val.shape}
    test  : {X_test.shape}
""")
# Out:
# Shapes
# ======
#     train : (1120, 20)
#     val   : (280, 20)
#     test  : (600, 20)

# %% [markdown]
# ## Optuna

# %%
N_TRIALS = 300

# %%
accuracies_train, precisions_train, recalls_train, f1s_train = [], [], [], []
accuracies_val, precisions_val, recalls_val, f1s_val = [], [], [], []
accuracies_test, precisions_test, recalls_test, f1s_test = [], [], [], []

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 2, 15)
    min_samples_split = trial.suggest_float('min_samples_split', 0.1, 1.0)
    min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.1, 1.0)
    
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('classifier', RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=RANDOM_SEED
        ))
    ])
        
    pipeline.fit(X_tra, y_tra)

    y_pred_train = pipeline.predict(X_tra)
    y_pred_val = pipeline.predict(X_val)
    y_test_pred = pipeline.predict(X_test_scaled)
    
    prec_train = precision_score(y_tra, y_pred_train, average='macro', zero_division=0)
    prec_val = precision_score(y_val, y_pred_val, average='macro', zero_division=0)
    prec_test = precision_score(y_test, y_test_pred, average='macro', zero_division=0)

    precisions_train.append(prec_train)
    precisions_val.append(prec_val)
    precisions_test.append(prec_test)

    return prec_val

# %%
start_time = time.time()

# Creating a study and running Optuna optimization.
study = optuna.create_study(study_name='my_optuna_study',
                            direction='maximize')
study.optimize(objective, n_trials=N_TRIALS)

elapsed_time = time.time() - start_time
elapsed_minutes, elapsed_seconds = int(elapsed_time // 60), int(elapsed_time % 60)
# Out:
# [I 2023-08-12 18:13:49,249] A new study created in memory with name: my_optuna_study
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:49,591] Trial 0 finished with value: 0.0625 and parameters: {'n_estimators': 165, 'max_depth': 10, 'min_samples_split': 0.5917415684316938, 'min_samples_leaf': 0.6234055626001828}. Best is trial 0 with value: 0.0625.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:49,735] Trial 1 finished with value: 0.4987412810688673 and parameters: {'n_estimators': 74, 'max_depth': 3, 'min_samples_split': 0.25198487434175965, 'min_samples_leaf': 0.19172074398751604}. Best is trial 1 with value: 0.4987412810688673.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:50,078] Trial 2 finished with value: 0.6472599784510291 and parameters: {'n_estimators': 199, 'max_depth': 8, 'min_samples_split': 0.4277934479858311, 'min_samples_leaf': 0.12290135700734205}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:50,483] Trial 3 finished with value: 0.598221916971917 and parameters: {'n_estimators': 251, 'max_depth': 8, 'min_samples_split': 0.6240110636321347, 'min_samples_leaf': 0.12493853564640534}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:50,824] Trial 4 finished with value: 0.0625 and parameters: {'n_estimators': 231, 'max_depth': 7, 'min_samples_split': 0.42554966548146733, 'min_samples_leaf': 0.3463787505213284}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:51,041] Trial 5 finished with value: 0.5403225951507302 and parameters: {'n_estimators': 135, 'max_depth': 9, 'min_samples_split': 0.2554904277868284, 'min_samples_leaf': 0.2929505218813469}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:51,373] Trial 6 finished with value: 0.0625 and parameters: {'n_estimators': 224, 'max_depth': 10, 'min_samples_split': 0.7862684588231353, 'min_samples_leaf': 0.4166301696704612}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:51,777] Trial 7 finished with value: 0.0625 and parameters: {'n_estimators': 241, 'max_depth': 7, 'min_samples_split': 0.8069415895911102, 'min_samples_leaf': 0.8768985515519501}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:52,116] Trial 8 finished with value: 0.0625 and parameters: {'n_estimators': 168, 'max_depth': 9, 'min_samples_split': 0.7304554367852851, 'min_samples_leaf': 0.8151013396769331}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:52,290] Trial 9 finished with value: 0.5214551151739586 and parameters: {'n_estimators': 68, 'max_depth': 7, 'min_samples_split': 0.5056490016716921, 'min_samples_leaf': 0.22996877381820674}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:52,943] Trial 10 finished with value: 0.0625 and parameters: {'n_estimators': 299, 'max_depth': 14, 'min_samples_split': 0.9732198098608585, 'min_samples_leaf': 0.49292305380906604}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:53,500] Trial 11 finished with value: 0.6451946554530656 and parameters: {'n_estimators': 284, 'max_depth': 3, 'min_samples_split': 0.3822045006825783, 'min_samples_leaf': 0.11021150603283734}. Best is trial 2 with value: 0.6472599784510291.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:54,065] Trial 12 finished with value: 0.7246480765097787 and parameters: {'n_estimators': 294, 'max_depth': 2, 'min_samples_split': 0.10063922203225772, 'min_samples_leaf': 0.14358290108872715}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:54,265] Trial 13 finished with value: 0.7131667674430833 and parameters: {'n_estimators': 115, 'max_depth': 2, 'min_samples_split': 0.11706472026589415, 'min_samples_leaf': 0.1058120638419133}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:54,472] Trial 14 finished with value: 0.5376934511405629 and parameters: {'n_estimators': 120, 'max_depth': 2, 'min_samples_split': 0.10154464846617373, 'min_samples_leaf': 0.2838836098137003}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:54,677] Trial 15 finished with value: 0.0625 and parameters: {'n_estimators': 115, 'max_depth': 5, 'min_samples_split': 0.10277965467834047, 'min_samples_leaf': 0.3587112008900293}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:54,844] Trial 16 finished with value: 0.5538974028007746 and parameters: {'n_estimators': 94, 'max_depth': 4, 'min_samples_split': 0.26163682821615986, 'min_samples_leaf': 0.22560502518538414}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:55,078] Trial 17 finished with value: 0.0625 and parameters: {'n_estimators': 148, 'max_depth': 5, 'min_samples_split': 0.16381327344793795, 'min_samples_leaf': 0.4638283139090479}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:55,467] Trial 18 finished with value: 0.0625 and parameters: {'n_estimators': 274, 'max_depth': 13, 'min_samples_split': 0.20672408487188088, 'min_samples_leaf': 0.599972467297752}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:55,784] Trial 19 finished with value: 0.5777087355212355 and parameters: {'n_estimators': 206, 'max_depth': 2, 'min_samples_split': 0.33481337106609727, 'min_samples_leaf': 0.20655433807037077}. Best is trial 12 with value: 0.7246480765097787.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:56,103] Trial 20 finished with value: 0.7353664155550949 and parameters: {'n_estimators': 197, 'max_depth': 5, 'min_samples_split': 0.3120523317420299, 'min_samples_leaf': 0.10494434397498867}. Best is trial 20 with value: 0.7353664155550949.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:56,278] Trial 21 finished with value: 0.7248780912574015 and parameters: {'n_estimators': 95, 'max_depth': 5, 'min_samples_split': 0.16225717510759669, 'min_samples_leaf': 0.12348296736144884}. Best is trial 20 with value: 0.7353664155550949.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:56,663] Trial 22 finished with value: 0.58270523325141 and parameters: {'n_estimators': 194, 'max_depth': 5, 'min_samples_split': 0.20568958168087442, 'min_samples_leaf': 0.18432304507133068}. Best is trial 20 with value: 0.7353664155550949.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:57,152] Trial 23 finished with value: 0.5420797287818564 and parameters: {'n_estimators': 263, 'max_depth': 4, 'min_samples_split': 0.3219677706050121, 'min_samples_leaf': 0.2934658807565482}. Best is trial 20 with value: 0.7353664155550949.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:57,277] Trial 24 finished with value: 0.5170493670215583 and parameters: {'n_estimators': 51, 'max_depth': 6, 'min_samples_split': 0.17497986091744622, 'min_samples_leaf': 0.17780839862010514}. Best is trial 20 with value: 0.7353664155550949.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:57,636] Trial 25 finished with value: 0.7397557677799131 and parameters: {'n_estimators': 179, 'max_depth': 4, 'min_samples_split': 0.31641338937469393, 'min_samples_leaf': 0.10050738215315894}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:57,979] Trial 26 finished with value: 0.5448222866260439 and parameters: {'n_estimators': 186, 'max_depth': 6, 'min_samples_split': 0.32053339685925253, 'min_samples_leaf': 0.25432371573191076}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:58,284] Trial 27 finished with value: 0.6343873517786561 and parameters: {'n_estimators': 152, 'max_depth': 4, 'min_samples_split': 0.4564325294228553, 'min_samples_leaf': 0.10384324881884897}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:58,629] Trial 28 finished with value: 0.5919415648159135 and parameters: {'n_estimators': 217, 'max_depth': 12, 'min_samples_split': 0.3701884576043316, 'min_samples_leaf': 0.18479184989839864}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:58,897] Trial 29 finished with value: 0.0625 and parameters: {'n_estimators': 180, 'max_depth': 6, 'min_samples_split': 0.28746793762998757, 'min_samples_leaf': 0.35459466325344363}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:59,141] Trial 30 finished with value: 0.5467741307691829 and parameters: {'n_estimators': 153, 'max_depth': 11, 'min_samples_split': 0.2192781596972163, 'min_samples_leaf': 0.23134558073131878}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:59,485] Trial 31 finished with value: 0.6496323455630612 and parameters: {'n_estimators': 209, 'max_depth': 3, 'min_samples_split': 0.16208241365983608, 'min_samples_leaf': 0.15649622137192276}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:59,656] Trial 32 finished with value: 0.6345959595959596 and parameters: {'n_estimators': 97, 'max_depth': 3, 'min_samples_split': 0.2677697168560462, 'min_samples_leaf': 0.1613374250826986}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:13:59,939] Trial 33 finished with value: 0.708832925409528 and parameters: {'n_estimators': 168, 'max_depth': 4, 'min_samples_split': 0.15553723528867003, 'min_samples_leaf': 0.1432390239393975}. Best is trial 25 with value: 0.7397557677799131.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:00,178] Trial 34 finished with value: 0.77032499322783 and parameters: {'n_estimators': 135, 'max_depth': 5, 'min_samples_split': 0.2151833563889205, 'min_samples_leaf': 0.10077162236814623}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:00,356] Trial 35 finished with value: 0.7638381115189539 and parameters: {'n_estimators': 94, 'max_depth': 5, 'min_samples_split': 0.22751551981173074, 'min_samples_leaf': 0.10145054555226256}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:00,582] Trial 36 finished with value: 0.5472208194018761 and parameters: {'n_estimators': 133, 'max_depth': 8, 'min_samples_split': 0.37762991132913803, 'min_samples_leaf': 0.255922818816149}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:00,821] Trial 37 finished with value: 0.7548104381874997 and parameters: {'n_estimators': 135, 'max_depth': 6, 'min_samples_split': 0.23661271264826567, 'min_samples_leaf': 0.1005068485400271}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:01,049] Trial 38 finished with value: 0.5696001139817629 and parameters: {'n_estimators': 132, 'max_depth': 7, 'min_samples_split': 0.2291279594730718, 'min_samples_leaf': 0.20383496699491455}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:01,194] Trial 39 finished with value: 0.5336054537638595 and parameters: {'n_estimators': 82, 'max_depth': 6, 'min_samples_split': 0.27403672477540497, 'min_samples_leaf': 0.2991957328199588}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:01,381] Trial 40 finished with value: 0.6054857266793358 and parameters: {'n_estimators': 108, 'max_depth': 8, 'min_samples_split': 0.21931864468409648, 'min_samples_leaf': 0.16459273606156677}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:01,652] Trial 41 finished with value: 0.7303138448636358 and parameters: {'n_estimators': 160, 'max_depth': 5, 'min_samples_split': 0.3079706218400612, 'min_samples_leaf': 0.10143603006700914}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:01,897] Trial 42 finished with value: 0.7548104381874997 and parameters: {'n_estimators': 140, 'max_depth': 4, 'min_samples_split': 0.2461798843612153, 'min_samples_leaf': 0.10195499588706913}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:02,137] Trial 43 finished with value: 0.6514060053421755 and parameters: {'n_estimators': 140, 'max_depth': 3, 'min_samples_split': 0.24900247542096912, 'min_samples_leaf': 0.15888567887202232}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:02,348] Trial 44 finished with value: 0.5745625295768005 and parameters: {'n_estimators': 126, 'max_depth': 4, 'min_samples_split': 0.3618919571656935, 'min_samples_leaf': 0.20466794689609713}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:02,630] Trial 45 finished with value: 0.6309153565732513 and parameters: {'n_estimators': 175, 'max_depth': 7, 'min_samples_split': 0.41334161582577844, 'min_samples_leaf': 0.14013268035048776}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:02,866] Trial 46 finished with value: 0.5405020004240961 and parameters: {'n_estimators': 141, 'max_depth': 6, 'min_samples_split': 0.2739444012724087, 'min_samples_leaf': 0.2632113483091855}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:03,017] Trial 47 finished with value: 0.7603207969108556 and parameters: {'n_estimators': 75, 'max_depth': 15, 'min_samples_split': 0.19723307343377622, 'min_samples_leaf': 0.10133710161745949}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:03,140] Trial 48 finished with value: 0.3843805309734513 and parameters: {'n_estimators': 59, 'max_depth': 15, 'min_samples_split': 0.20056488730412508, 'min_samples_leaf': 0.31892436510075733}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:03,323] Trial 49 finished with value: 0.5270828428723165 and parameters: {'n_estimators': 77, 'max_depth': 9, 'min_samples_split': 0.25560000573324343, 'min_samples_leaf': 0.23017737139091032}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:03,545] Trial 50 finished with value: 0.6922107630272952 and parameters: {'n_estimators': 105, 'max_depth': 11, 'min_samples_split': 0.13891986837333853, 'min_samples_leaf': 0.13696133155938017}. Best is trial 34 with value: 0.77032499322783.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:03,748] Trial 51 finished with value: 0.7744031180837103 and parameters: {'n_estimators': 85, 'max_depth': 4, 'min_samples_split': 0.19064432714274787, 'min_samples_leaf': 0.10086858822211572}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:03,950] Trial 52 finished with value: 0.5418468358217073 and parameters: {'n_estimators': 86, 'max_depth': 15, 'min_samples_split': 0.19475931852480455, 'min_samples_leaf': 0.1827953820353433}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:04,088] Trial 53 finished with value: 0.6460470103354748 and parameters: {'n_estimators': 66, 'max_depth': 3, 'min_samples_split': 0.18669788297217849, 'min_samples_leaf': 0.14947017249005393}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:04,279] Trial 54 finished with value: 0.7136862041467305 and parameters: {'n_estimators': 106, 'max_depth': 5, 'min_samples_split': 0.13611969247630473, 'min_samples_leaf': 0.1306439721317694}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:04,485] Trial 55 finished with value: 0.5645839649564591 and parameters: {'n_estimators': 121, 'max_depth': 10, 'min_samples_split': 0.240958467636722, 'min_samples_leaf': 0.2123862178677739}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:04,658] Trial 56 finished with value: 0.7167863536328997 and parameters: {'n_estimators': 89, 'max_depth': 4, 'min_samples_split': 0.23486189484251324, 'min_samples_leaf': 0.12877696650241055}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:04,800] Trial 57 finished with value: 0.5336468025907681 and parameters: {'n_estimators': 76, 'max_depth': 7, 'min_samples_split': 0.12672785374300316, 'min_samples_leaf': 0.17785171993316778}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:04,929] Trial 58 finished with value: 0.5385421706176423 and parameters: {'n_estimators': 67, 'max_depth': 14, 'min_samples_split': 0.17662552609808213, 'min_samples_leaf': 0.24345449642599382}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:05,106] Trial 59 finished with value: 0.5483205782312925 and parameters: {'n_estimators': 101, 'max_depth': 2, 'min_samples_split': 0.28824636687931293, 'min_samples_leaf': 0.20286145209920226}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:05,308] Trial 60 finished with value: 0.7075066854862199 and parameters: {'n_estimators': 112, 'max_depth': 6, 'min_samples_split': 0.13157960509955927, 'min_samples_leaf': 0.13005972711681826}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:05,587] Trial 61 finished with value: 0.7085392903352752 and parameters: {'n_estimators': 164, 'max_depth': 4, 'min_samples_split': 0.34175192744559946, 'min_samples_leaf': 0.10379506102900443}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:05,838] Trial 62 finished with value: 0.7544695879160643 and parameters: {'n_estimators': 143, 'max_depth': 5, 'min_samples_split': 0.1995987990582575, 'min_samples_leaf': 0.11175599415171814}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:06,099] Trial 63 finished with value: 0.7583893780060325 and parameters: {'n_estimators': 145, 'max_depth': 5, 'min_samples_split': 0.18903699471643368, 'min_samples_leaf': 0.10125426948646613}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:06,316] Trial 64 finished with value: 0.6225787534898987 and parameters: {'n_estimators': 124, 'max_depth': 5, 'min_samples_split': 0.10147976197638667, 'min_samples_leaf': 0.16797725954632223}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:06,547] Trial 65 finished with value: 0.7227987109346691 and parameters: {'n_estimators': 131, 'max_depth': 3, 'min_samples_split': 0.22655727562043307, 'min_samples_leaf': 0.1311986671645896}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:06,659] Trial 66 finished with value: 0.516079591954406 and parameters: {'n_estimators': 51, 'max_depth': 6, 'min_samples_split': 0.1573165510980453, 'min_samples_leaf': 0.18467484656592997}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:06,926] Trial 67 finished with value: 0.7460211069110485 and parameters: {'n_estimators': 155, 'max_depth': 7, 'min_samples_split': 0.2983716302816354, 'min_samples_leaf': 0.10033924952456474}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:07,132] Trial 68 finished with value: 0.6587967480591952 and parameters: {'n_estimators': 115, 'max_depth': 5, 'min_samples_split': 0.17579662786834085, 'min_samples_leaf': 0.15343969450461373}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:07,373] Trial 69 finished with value: 0.5241234153344526 and parameters: {'n_estimators': 147, 'max_depth': 4, 'min_samples_split': 0.2536796145193046, 'min_samples_leaf': 0.2298023649660944}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:07,492] Trial 70 finished with value: 0.46682531483667844 and parameters: {'n_estimators': 60, 'max_depth': 3, 'min_samples_split': 0.22066010553881002, 'min_samples_leaf': 0.1999636878912016}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:07,743] Trial 71 finished with value: 0.7404416212946158 and parameters: {'n_estimators': 141, 'max_depth': 5, 'min_samples_split': 0.19650725391327634, 'min_samples_leaf': 0.12243443523862887}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:07,975] Trial 72 finished with value: 0.7572222513879893 and parameters: {'n_estimators': 127, 'max_depth': 5, 'min_samples_split': 0.1950256984303001, 'min_samples_leaf': 0.10264594319617704}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:08,150] Trial 73 finished with value: 0.6405373958918881 and parameters: {'n_estimators': 96, 'max_depth': 6, 'min_samples_split': 0.29000048357749564, 'min_samples_leaf': 0.15549099217804707}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:08,426] Trial 74 finished with value: 0.7082697395197396 and parameters: {'n_estimators': 127, 'max_depth': 4, 'min_samples_split': 0.15398014960998319, 'min_samples_leaf': 0.1317106844161159}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:08,631] Trial 75 finished with value: 0.5451014873172284 and parameters: {'n_estimators': 117, 'max_depth': 4, 'min_samples_split': 0.24693331100707183, 'min_samples_leaf': 0.1738965291708981}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:08,796] Trial 76 finished with value: 0.7744031180837103 and parameters: {'n_estimators': 85, 'max_depth': 5, 'min_samples_split': 0.17878457282605945, 'min_samples_leaf': 0.10051680768180506}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:08,970] Trial 77 finished with value: 0.6759899527186761 and parameters: {'n_estimators': 89, 'max_depth': 6, 'min_samples_split': 0.11526311008351757, 'min_samples_leaf': 0.14895375934936994}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:09,131] Trial 78 finished with value: 0.7230876382667251 and parameters: {'n_estimators': 81, 'max_depth': 5, 'min_samples_split': 0.18432413247331902, 'min_samples_leaf': 0.11971778619442802}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:09,300] Trial 79 finished with value: 0.540518603018603 and parameters: {'n_estimators': 72, 'max_depth': 7, 'min_samples_split': 0.2140723083704927, 'min_samples_leaf': 0.18442488350982797}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:09,504] Trial 80 finished with value: 0.5559615592822423 and parameters: {'n_estimators': 92, 'max_depth': 8, 'min_samples_split': 0.1581509743168695, 'min_samples_leaf': 0.215408788371163}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:09,802] Trial 81 finished with value: 0.7551256215049318 and parameters: {'n_estimators': 136, 'max_depth': 5, 'min_samples_split': 0.2682843192812396, 'min_samples_leaf': 0.10147361605809102}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:10,030] Trial 82 finished with value: 0.7070042530568846 and parameters: {'n_estimators': 101, 'max_depth': 5, 'min_samples_split': 0.2718073271885229, 'min_samples_leaf': 0.1253654319204403}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:10,350] Trial 83 finished with value: 0.6433720048442055 and parameters: {'n_estimators': 155, 'max_depth': 6, 'min_samples_split': 0.2123264699679604, 'min_samples_leaf': 0.1558722311689568}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:10,619] Trial 84 finished with value: 0.7578925631604432 and parameters: {'n_estimators': 111, 'max_depth': 5, 'min_samples_split': 0.17478165704117196, 'min_samples_leaf': 0.10049121504781447}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:10,834] Trial 85 finished with value: 0.6755155601220644 and parameters: {'n_estimators': 111, 'max_depth': 5, 'min_samples_split': 0.18737224318766937, 'min_samples_leaf': 0.14400899424732383}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:10,999] Trial 86 finished with value: 0.7495372854751152 and parameters: {'n_estimators': 81, 'max_depth': 12, 'min_samples_split': 0.13374155117146272, 'min_samples_leaf': 0.10055601368408218}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:11,245] Trial 87 finished with value: 0.7221576522139463 and parameters: {'n_estimators': 100, 'max_depth': 4, 'min_samples_split': 0.16479715323875874, 'min_samples_leaf': 0.12406691041836651}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:11,547] Trial 88 finished with value: 0.5940975724371906 and parameters: {'n_estimators': 128, 'max_depth': 5, 'min_samples_split': 0.11490296153365945, 'min_samples_leaf': 0.171435984488447}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:11,770] Trial 89 finished with value: 0.5384786000791424 and parameters: {'n_estimators': 118, 'max_depth': 5, 'min_samples_split': 0.14457110256509487, 'min_samples_leaf': 0.1944929711368555}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:11,975] Trial 90 finished with value: 0.6783675612729093 and parameters: {'n_estimators': 84, 'max_depth': 6, 'min_samples_split': 0.21073635501291244, 'min_samples_leaf': 0.1433838518567791}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:12,475] Trial 91 finished with value: 0.730209994683679 and parameters: {'n_estimators': 134, 'max_depth': 4, 'min_samples_split': 0.23424139465320049, 'min_samples_leaf': 0.11675469809869668}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:12,782] Trial 92 finished with value: 0.733612296189913 and parameters: {'n_estimators': 121, 'max_depth': 5, 'min_samples_split': 0.1788436898630731, 'min_samples_leaf': 0.11733827881654409}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:13,099] Trial 93 finished with value: 0.6317295923171076 and parameters: {'n_estimators': 149, 'max_depth': 6, 'min_samples_split': 0.26676580733069294, 'min_samples_leaf': 0.16476004409295397}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:13,349] Trial 94 finished with value: 0.7594827586206897 and parameters: {'n_estimators': 137, 'max_depth': 4, 'min_samples_split': 0.2345162159761993, 'min_samples_leaf': 0.10144867862505186}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:13,497] Trial 95 finished with value: 0.6635612812228646 and parameters: {'n_estimators': 72, 'max_depth': 4, 'min_samples_split': 0.196807673086959, 'min_samples_leaf': 0.14293230181470049}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:13,744] Trial 96 finished with value: 0.7325848733416318 and parameters: {'n_estimators': 106, 'max_depth': 5, 'min_samples_split': 0.14622023335465595, 'min_samples_leaf': 0.1196863012509541}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:14:14,026] Trial 97 finished with value: 0.5946079749271238 and parameters: {'n_estimators': 136, 'max_depth': 4, 'min_samples_split': 0.22835794189453504, 'min_samples_leaf': 0.1703108514664578}. Best is trial 51 with value: 0.7744031180837103.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# [I 2023-08-12 18:15:13,049] Trial 267 finished with value: 0.7225637837339965 and parameters: {'n_estimators': 184, 'max_depth': 8, 'min_samples_split': 0.1535678132743951, 'min_samples_leaf': 0.13209537791176829}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:13,416] Trial 268 finished with value: 0.0625 and parameters: {'n_estimators': 175, 'max_depth': 6, 'min_samples_split': 0.1995810043501155, 'min_samples_leaf': 0.33880048304227683}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:13,726] Trial 269 finished with value: 0.0625 and parameters: {'n_estimators': 194, 'max_depth': 7, 'min_samples_split': 0.130548047181435, 'min_samples_leaf': 0.36075459326038806}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:14,055] Trial 270 finished with value: 0.7036776804314842 and parameters: {'n_estimators': 188, 'max_depth': 7, 'min_samples_split': 0.17512300951548201, 'min_samples_leaf': 0.14847888789858102}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:14,394] Trial 271 finished with value: 0.7770466272633454 and parameters: {'n_estimators': 178, 'max_depth': 8, 'min_samples_split': 0.1391604012133565, 'min_samples_leaf': 0.10029958553269072}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:14,749] Trial 272 finished with value: 0.7381313937644877 and parameters: {'n_estimators': 202, 'max_depth': 7, 'min_samples_split': 0.1199500237169427, 'min_samples_leaf': 0.11737253927505684}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:15,103] Trial 273 finished with value: 0.7307922346966053 and parameters: {'n_estimators': 182, 'max_depth': 7, 'min_samples_split': 0.10088488379281596, 'min_samples_leaf': 0.12871140514153193}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:15,410] Trial 274 finished with value: 0.7369361667480867 and parameters: {'n_estimators': 171, 'max_depth': 6, 'min_samples_split': 0.16569428724683072, 'min_samples_leaf': 0.11568730512610324}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:15,736] Trial 275 finished with value: 0.7233184689706429 and parameters: {'n_estimators': 188, 'max_depth': 8, 'min_samples_split': 0.14931616149946966, 'min_samples_leaf': 0.14068464167948744}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:16,080] Trial 276 finished with value: 0.7697194858804766 and parameters: {'n_estimators': 196, 'max_depth': 7, 'min_samples_split': 0.12453387945568424, 'min_samples_leaf': 0.10047518430220952}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:16,385] Trial 277 finished with value: 0.5686747886824106 and parameters: {'n_estimators': 178, 'max_depth': 7, 'min_samples_split': 0.19416775542447448, 'min_samples_leaf': 0.17896522546453392}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:16,697] Trial 278 finished with value: 0.5958880209018298 and parameters: {'n_estimators': 186, 'max_depth': 7, 'min_samples_split': 0.5426718316527621, 'min_samples_leaf': 0.11570440061674594}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:17,034] Trial 279 finished with value: 0.5457637916277622 and parameters: {'n_estimators': 208, 'max_depth': 6, 'min_samples_split': 0.10040869740690476, 'min_samples_leaf': 0.28935027780360223}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:17,298] Trial 280 finished with value: 0.0625 and parameters: {'n_estimators': 164, 'max_depth': 8, 'min_samples_split': 0.15165508827581894, 'min_samples_leaf': 0.5542160943779814}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:17,634] Trial 281 finished with value: 0.663578036957752 and parameters: {'n_estimators': 192, 'max_depth': 7, 'min_samples_split': 0.17363468248150932, 'min_samples_leaf': 0.15304645198854655}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:17,944] Trial 282 finished with value: 0.6317215803736984 and parameters: {'n_estimators': 182, 'max_depth': 8, 'min_samples_split': 0.3785361778787836, 'min_samples_leaf': 0.12951564825835166}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:18,239] Trial 283 finished with value: 0.6288871496720334 and parameters: {'n_estimators': 173, 'max_depth': 7, 'min_samples_split': 0.4000481815276098, 'min_samples_leaf': 0.11604602731729284}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:18,583] Trial 284 finished with value: 0.0625 and parameters: {'n_estimators': 189, 'max_depth': 7, 'min_samples_split': 0.12830311135462258, 'min_samples_leaf': 0.4198675287450281}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:19,038] Trial 285 finished with value: 0.0625 and parameters: {'n_estimators': 260, 'max_depth': 9, 'min_samples_split': 0.13819877518556112, 'min_samples_leaf': 0.38640816149553114}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:19,332] Trial 286 finished with value: 0.0625 and parameters: {'n_estimators': 180, 'max_depth': 6, 'min_samples_split': 0.1159363560213878, 'min_samples_leaf': 0.5923245241727861}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:19,682] Trial 287 finished with value: 0.752211830131446 and parameters: {'n_estimators': 199, 'max_depth': 8, 'min_samples_split': 0.16039255444761716, 'min_samples_leaf': 0.11431891711066366}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:19,994] Trial 288 finished with value: 0.7805416177360236 and parameters: {'n_estimators': 170, 'max_depth': 7, 'min_samples_split': 0.1861515444501117, 'min_samples_leaf': 0.10054871813977133}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:20,296] Trial 289 finished with value: 0.7304921075301509 and parameters: {'n_estimators': 168, 'max_depth': 7, 'min_samples_split': 0.20221503495685067, 'min_samples_leaf': 0.13755630519725975}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:20,576] Trial 290 finished with value: 0.5848606133714348 and parameters: {'n_estimators': 161, 'max_depth': 7, 'min_samples_split': 0.18761722419136012, 'min_samples_leaf': 0.19371895347150758}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:20,884] Trial 291 finished with value: 0.7805416177360236 and parameters: {'n_estimators': 170, 'max_depth': 8, 'min_samples_split': 0.10047000451766241, 'min_samples_leaf': 0.1001677679917842}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:21,144] Trial 292 finished with value: 0.0625 and parameters: {'n_estimators': 166, 'max_depth': 8, 'min_samples_split': 0.47085870352823656, 'min_samples_leaf': 0.7665330053789049}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:21,436] Trial 293 finished with value: 0.5410641369553835 and parameters: {'n_estimators': 172, 'max_depth': 8, 'min_samples_split': 0.112670511028196, 'min_samples_leaf': 0.2998002346065175}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:21,811] Trial 294 finished with value: 0.5402833380719091 and parameters: {'n_estimators': 176, 'max_depth': 9, 'min_samples_split': 0.10156046287515037, 'min_samples_leaf': 0.2722001491223656}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:22,222] Trial 295 finished with value: 0.6389270038933201 and parameters: {'n_estimators': 173, 'max_depth': 8, 'min_samples_split': 0.3685732998700779, 'min_samples_leaf': 0.13021059796556755}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:22,611] Trial 296 finished with value: 0.11326530612244898 and parameters: {'n_estimators': 164, 'max_depth': 8, 'min_samples_split': 0.6562548864738187, 'min_samples_leaf': 0.10045841905014466}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:22,965] Trial 297 finished with value: 0.5898134076325565 and parameters: {'n_estimators': 168, 'max_depth': 7, 'min_samples_split': 0.34218976014594904, 'min_samples_leaf': 0.16038018454368003}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:23,304] Trial 298 finished with value: 0.5637741232564913 and parameters: {'n_estimators': 215, 'max_depth': 6, 'min_samples_split': 0.12117439658747743, 'min_samples_leaf': 0.247011775371508}. Best is trial 209 with value: 0.7852965814352387.
# /Users/clemens.woest/opt/anaconda3/envs/bayes_opt_battle_4/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# [I 2023-08-12 18:15:23,617] Trial 299 finished with value: 0.7771294664618053 and parameters: {'n_estimators': 177, 'max_depth': 7, 'min_samples_split': 0.18311985686816484, 'min_samples_leaf': 0.10008548186440998}. Best is trial 209 with value: 0.7852965814352387.

# %%
# The searched optimal parameters.
best_params = study.best_params

# Create the pipeline with the searched optimal parameters.
best_rfc = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', RandomForestClassifier(
        n_estimators=best_params['n_estimators'],
        max_depth=best_params['max_depth'],
        min_samples_split=best_params['min_samples_split'],
        min_samples_leaf=best_params['min_samples_leaf'],
        random_state=RANDOM_SEED,
    ))
])

# Train the final model on the searched optimal parameters.
best_rfc.fit(X_train_scaled, y_train)

# Train metrics.
y_train_pred = best_rfc.predict(X_train_scaled)
train_acc = accuracy_score(y_train, y_train_pred)
train_prec = precision_score(y_train, y_train_pred, average='macro', zero_division=0)
train_rec = recall_score(y_train, y_train_pred, average='macro', zero_division=0)
train_f1 = f1_score(y_train, y_train_pred, average='macro', zero_division=0)

# Test metrics.
y_test_pred = best_rfc.predict(X_test_scaled)
test_acc = accuracy_score(y_test, y_test_pred)
test_prec = precision_score(y_test, y_test_pred, average='macro', zero_division=0)
test_rec = recall_score(y_test, y_test_pred, average='macro', zero_division=0)
test_f1 = f1_score(y_test, y_test_pred, average='macro', zero_division=0)

print(f"""
Optuna Results
==============
                {'Train':<10}{'Test':<10}
    Accuracy  : {train_acc:<10.4f}{test_acc:<10.4f}
    Precision : {train_prec:<10.4f}{test_prec:<10.4f}
    Recall    : {train_rec:<10.4f}{test_rec:<10.4f}
    F1-Score  : {train_f1:<10.4f}{test_f1:<10.4f}

Tuning time: {elapsed_minutes} min {elapsed_seconds} sec

Best parameters:
""")
pp = pprint.PrettyPrinter()
pp.pprint(best_params)
# Out:
# Optuna Results
# ==============
#                 Train     Test
#     Accuracy  : 0.8214    0.7867
#     Precision : 0.8187    0.7780
#     Recall    : 0.8214    0.7867
#     F1-Score  : 0.8132    0.7727
#
# Tuning time: 1 min 34 sec
#
# Best parameters:
#
# {'max_depth': 7,
#  'min_samples_leaf': 0.10004490738183389,
#  'min_samples_split': 0.10023842198468587,
#  'n_estimators': 172}

# %% [markdown]
# #### Plots

# %%
plt.figure(figsize=(6, 3))

plt.plot(np.arange(1, N_TRIALS+1, 1), precisions_train, label='Train', alpha=0.7, color='C0');
plt.plot(np.arange(1, N_TRIALS+1, 1), precisions_test, label='Test', alpha=0.7, color='C1');

plt.xlabel("# Trials");
plt.ylabel("Precision");
plt.legend();

plt.title("Optuna");
plt.show();

# %%
precisions_test
# Out:
# [0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625,
#  0.0625]
